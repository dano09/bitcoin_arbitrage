# %% [markdown]
# Justin Dano <br>
# FE550 - Data Visualization Applications<br>
# Assignment #3<br>
# Due 10/11/2017<br>

# %% [markdown]
# #  Cryptocurrency Arbitrage - Liquidity and the Order Book

# %% [markdown]
# ## 1. Introduction
#
# As mentioned in previous assignments, the goal of the topic is to determine if trading cryptocurrencies can be a profitable endeavor. The previous two workbooks took an embryonic look at arbitrage opportunities present in the cryptocurrency markets. The research findings thus far has shown that arbitrage opportunities may indeed exist, and that they appear to be somewhat common. With that said, an investment strategy based on arbitrage trading may be feasible. The following analysis will dive deeper in cryptocurrency market microstructure and examine how much liquidity is actually available during an arbitrage opportunity. Specifically, the analysis aims to answer the following questions:
#
#
# <b> 1. How much liquidity do cryptocurrency exchanges have at a given moment in time? </b><br>
# <b> 2. How much Bitcoin is available for trading during an arbitrage opportunity? </b><br>
# <b> 3. Are cryptocurrency markets balanced?  </b>
#
# The analysis begins with setting up a mechanism to pull order book data from different exchanges. This data will be  stored in a .csv file so the findings presented can be duplicated. Next, Bokeh will be used to visualize the order book for each exchange. To visualize the arbitrage opportunity, two order books from different exchanges will be compared simultaneously. With both order books lined up together, the arbitrage opportunity can be visualized, along with the liquidity available for the opportunity.
#
# #### Technology Stack
# Python 3.6.1 <br>
# Anaconda 3-4.4.0 <br>
# Pandas 0.20.3 <br>
# Bokeh 0.12.9 <br>
# Developed on a Jupyter notebook.

# %%
# Import Modules and settings for styling
import urllib.request
import json
import time
import csv
import os
import numpy as np
import warnings
import pandas as pd
import pprint as pp
import locale
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import LinearAxis, Range1d, ColumnDataSource, NumeralTickFormatter

locale.setlocale( locale.LC_ALL, '' )
warnings.filterwarnings('ignore')

chart_styling = {'axis_size':'12pt', 
                 'title_size':'14pt', 
                 'font':'times',
                 'legend_pos': 'top_right',
                 'legend_font': '8pt'}

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="53cae7e0-f067-42df-8d50-396827bda6de">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## 2. Data Retrieval from CryptoWatch API
#
# The data used in the previous workbooks were rudimentary at best. Price levels were calculated based on actual trades, and did not consider the various orders present in the order book. To have a more accurate analysis of arbitrage opportunities, the liquidity, or actual amount of volume that can be bought and sold must be known.
#
# Order book data will be retrieved from the [Crypto Watch](https://cryptowat.ch/) API. Since no freely available historic order book data could be found, the following functions work to pull the current order book. Next, the order book data is saved into a .csv file, which will called in the following section. Future work will involve setting up a websocket to pull data and store it in a database.

# %% [markdown]
# #### Note: The following section does not need to be ran for analysis. It is presented simply to demonstrate how the data was retrieved.

# %%
def write_to_csv(filename, data, directory):
    """
    Creates CSV file from order book data
    :param filename: name of csv file to be created
    :param data: list of prices/amounts
    """

    # Creates CSV file
    with open('order_book_data/' + str(directory) + '/' + filename, 'w') as csvfile:
        csvout = csv.writer(csvfile)
        for row in data:
            csvout.writerow(row)

            
def format_order_book_data_and_save(exchange, timestamp):
    """
    Formats order book data and saves into csv file
    :param exchange: String - name of exchange used in cryptowatch
    :param timestamp: String - timestamp of order book. used to create unique directory 
    """
    
    # Assemble order book for CSV. The bids and asks are saved in different files.
    order_book = json.load(exchange[0])['result']
    asks = order_book['asks']
    bids = order_book['bids']

    csv_asks_file = exchange[1] + '_asks.csv'
    csv_bids_file = exchange[1] + '_bids.csv'

    write_to_csv(csv_asks_file, asks, timestamp)
    write_to_csv(csv_bids_file, bids, timestamp)

            
def get_order_book_data(list_of_exchanges):
    """
    Make HTTP Requests to pull order book data from Cryptowatch
    :param list_of_exchanges: list of different exchanges
    :return:
        exchange_responses: list of tuples (HTTP Response for Order book, name of exchange)
        timestamp: string of timestamp of data retrieval
    """
    
    exchange_responses = []

    for exchange in list_of_exchanges:
        # Read in data from Cryptowatch
        url = 'https://api.cryptowat.ch/markets/' + exchange + '/btcusd/orderbook'
        exchange_responses.append((urllib.request.urlopen(url), exchange))

    # Time will be off by a few microseconds. This analysis will assume they are equivalent for each exchange.
    timestamp = pd.to_datetime(time.time(), unit='s')

    return exchange_responses, timestamp    


order_book_responses, eob_timestamp = get_order_book_data(['gdax', 'kraken', 'bitstamp'])

# Creates unique Directory
os.makedirs('order_book_data/' + str(eob_timestamp))

for response in order_book_responses:
    format_order_book_data_and_save(response, eob_timestamp)

# %% [markdown]
# ## 3. Data Retrieval from CSV Files
#
# The snapshot of the order book for each exchange has been created and saved in a timestamp named directory. Going forward, all of the analysis is done over one particular microsecond of the order book on October 10th, 2017 at 4:29:21.338556 PM. To test locally, please perform the following steps:
#
# 1. Comment out the current <i>directory_path</i> variable </b>
# 2. Uncomment out the second <i>directory_path</i> variable, and add the path to the directory containing the .csv data which was submitted.
#
# The directory will be submitted with the exact timestamp presented below. Only thing that needs to be changed is the path where that directory is saved on the local computer.

# %%
def read_data(exchange, time_extension):
    """
    Reads order book data saved in .csv files
    :param exchange: String - identifies the order books exchange
    :param time_extension: String - timestamp of order book. Used to create unique directory
    :return: Dataframe - Order book data
    """    

    directory_path = r'/home/justin/PycharmProjects/bitcoin_arbitrage/order_book_data/' + time_extension
    #directory_path = r'your_path_to_submitted_data' + time_extension
    
    asks_file = directory_path + '/' + exchange + '_asks.csv'
    bids_file = directory_path + '/' + exchange + '_bids.csv'
  
    df_asks = pd.read_csv(asks_file, names=['ask_price', 'ask_volume'])
    df_bids = pd.read_csv(bids_file, names=['bid_price', 'bid_volume'])
    
    return pd.concat([df_bids, df_asks], axis=1)

sample_time = '2017-10-02 16:29:21.338665'
gdax_orderbook = read_data('gdax', sample_time)
kraken_orderbook = read_data('kraken', sample_time)
bitstamp_orderbook = read_data('bitstamp', sample_time)

gdax_orderbook.head()
# Out:
#    bid_price  bid_volume  ask_price  ask_volume
# 0    4408.43      6.1100    4408.44    1.330000
# 1    4408.42      2.0000    4408.45    0.010000
# 2    4408.35      0.2565    4408.46    0.010000
# 3    4408.20      0.2500    4408.50    0.098697
# 4    4408.05      0.0220    4409.08    3.670000

# %% [markdown]
# ## 4. Calculating Liquidity
#
# To visualize the order book, the amount of liquidity at each order needs to be calculated. This is done by taking the cumulative size of each order.

# %%
def calculate_liquidity(order_book):
    """
    Calculates liquidity by taking cumulative sum of volume for bids and asks
    :param order_book: Dataframe - Order book with bids/asks
    :return: Dataframe - Order book with bids/asks and liquidity
    """
    order_book['ask_liquidity'] = order_book['ask_volume'].cumsum()
    order_book['bid_liquidity'] = order_book['bid_volume'].cumsum()

    # Reorder columns to align order book
    cols = ['bid_liquidity', 'bid_volume', 'bid_price', 'ask_price', 'ask_volume', 'ask_liquidity']

    return order_book[cols]

gdax_orderbook = calculate_liquidity(gdax_orderbook)
kraken_orderbook = calculate_liquidity(kraken_orderbook)
bitstamp_orderbook = calculate_liquidity(bitstamp_orderbook)

gdax_orderbook.head()
# Out:
#    bid_liquidity  bid_volume  bid_price  ask_price  ask_volume  ask_liquidity
# 0         6.1100      6.1100    4408.43    4408.44    1.330000       1.330000
# 1         8.1100      2.0000    4408.42    4408.45    0.010000       1.340000
# 2         8.3665      0.2565    4408.35    4408.46    0.010000       1.350000
# 3         8.6165      0.2500    4408.20    4408.50    0.098697       1.448697
# 4         8.6385      0.0220    4408.05    4409.08    3.670000       5.118697

# %% [markdown]
# ## 5. Visualizing the Order Book
#
# Visualizing the order book will be done by making use of Bokeh's <i>patches</i> glyph. Each side of the order book will be represented by its own patch. First, the coordinates that outline the shape of the orders will be created. This is accomplished in the <i>generate_plot_coordinates()</i> function.

# %%
def generate_plot_coordinates(order_book, samples):
    """
    Generates the x and y coordinates used to create the shape of the order book.
    :param order_book: Dataframe - order book data to be visualized
    :param samples: Int - number of bids/asks to be plotted
    :return: Tuple - coordinates for the ask shape and bid shape
    """
    x_bid_coordinates = []
    y_bid_coordinates = []

    x_ask_coordinates = []
    y_ask_coordinates = []

    for i in range(samples):
        x_bid_coordinates.append(order_book['bid_price'][i])
        y_bid_coordinates.append(order_book['bid_liquidity'][i])

        x_ask_coordinates.append(order_book['ask_price'][i])
        y_ask_coordinates.append(order_book['ask_liquidity'][i])

    # Need to repeat first and last coordinate to create the bottom part of shape
    x_bid_coordinates = [x_bid_coordinates[0]] + x_bid_coordinates + [x_bid_coordinates[-1]]
    y_bid_coordinates = [0] + y_bid_coordinates + [0]

    x_ask_coordinates = [x_ask_coordinates[0]] + x_ask_coordinates + [x_ask_coordinates[-1]]
    y_ask_coordinates = [0] + y_ask_coordinates + [0]

    return x_bid_coordinates, x_ask_coordinates, y_bid_coordinates, y_ask_coordinates

# %% [markdown]
# The next function <i>plot_order_book()</i> is now used to create the plot and add styling to the visualization. It calls the previous function <i>generate_plot_coordinates()</i>.

# %%
def plot_order_book(order_book, order_count, exchange, ob_time, styling):
    """
    Creates a visualization of the Order Book Bids/Asks
    :param order_book: Dataframe - Order Book data 
    :param exchange: String - Name of the order books exchange
    :param ob_time: String - Timestamp of order book
    :param styling: Dict - Styling parameters
    """
    
    # Get x/y coordinates for both bids and asks of order book
    order_book_coords  = generate_plot_coordinates(order_book, order_count)
           
    # Create a new plot with a title and axis labels
    plot_title = ' Order Book for ' + str(exchange) + ' at ' + ob_time
    p = figure(title=plot_title,
               x_axis_label='USD/BTC', 
               y_axis_label='Liquidity (BTC\'s)',
               plot_width=950, 
               plot_height=500
              )

    # Create source for the data points, colors, and legend
    source = ColumnDataSource(dict(
        x_axis = [order_book_coords[0], order_book_coords[1]],
        y_axis = [order_book_coords[2], order_book_coords[3]],
        color = ['green', 'red'],
        label = ['Bids', 'Asks']
    ))    
    
    # Plot order book with coordinates
    p.patches(xs='x_axis', ys='y_axis', color='color', legend='label', alpha=0.5, line_width=2, source=source)

    # Graph Formatting
    p.xaxis.formatter = NumeralTickFormatter(format="=$ 0,0[.]00")
    p.title.text_font_size = styling['title_size']
    p.xaxis.axis_label_text_font_size = styling['axis_size']
    p.yaxis.axis_label_text_font_size = styling['axis_size']
    
    p.title.text_font = styling['font']
    p.xaxis.axis_label_text_font = styling['font']
    p.yaxis.axis_label_text_font = styling['font']
   
    show(p)

# %%
# Parameter to define the top bids/asks to visualize
order_count = 99
plot_order_book(bitstamp_orderbook, order_count, 'Bitstamp', sample_time, chart_styling)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e2d589f8-7a4f-470b-9046-677b21dc0b27"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e2d589f8-7a4f-470b-9046-677b21dc0b27");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e2d589f8-7a4f-470b-9046-677b21dc0b27");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e2d589f8-7a4f-470b-9046-677b21dc0b27' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"32aaba04-bb4c-452b-8df2-996cd4f4f2de":{"roots":{"references":[{"attributes":{"axis_label":"Liquidity (BTC's)","axis_label_text_font":"times","axis_label_text_font_size":{"value":"12pt"},"formatter":{"id":"82c410d6-f772-4fde-b8a1-c92ed1592d56","type":"BasicTickFormatter"},"plot":{"id":"aa41c407-0e63-4d5d-87d0-e6781ec29fb8","subtype":"Figure","type":"Plot"},"ticker":{"id":"ac6ad58b-55fc-4ab9-8aa4-7719bbfa747a","type":"BasicTicker"}},"id":"c8edd21b-7363-4ffe-8218-bdf36ef17acd","type":"LinearAxis"},{"attributes":{"below":[{"id":"c602c728-031d-4f68-8397-d24251ef8173","type":"LinearAxis"}],"left":[{"id":"c8edd21b-7363-4ffe-8218-bdf36ef17acd","type":"LinearAxis"}],"plot_height":500,"plot_width":950,"renderers":[{"id":"c602c728-031d-4f68-8397-d24251ef8173","type":"LinearAxis"},{"id":"63fd0555-f5c8-4b81-97c3-a1eb4bd77be5","type":"Grid"},{"id":"c8edd21b-7363-4ffe-8218-bdf36ef17acd","type":"LinearAxis"},{"id":"14d332ad-9faf-47d6-85f8-b7b983f66e8d","type":"Grid"},{"id":"a4384faa-4612-4201-98b9-5191f83fc9bc","type":"BoxAnnotation"},{"id":"127aa09c-0ea3-4614-8ab5-bec1af0561bc","type":"Legend"},{"id":"8e7c3e3b-a708-45fe-a9e8-d8d60c6ed478","type":"GlyphRenderer"}],"title":{"id":"33435578-dc76-4558-b317-4297dbd955cf","type":"Title"},"tool_events":{"id":"e209bf0e-2a7b-41b1-81e3-dd1194610461","type":"ToolEvents"},"toolbar":{"id":"8ad8ade5-7c75-4e0c-843f-6260b1dedcd3","type":"Toolbar"},"x_range":{"id":"3f05698f-6721-4260-9dc5-308802ddf95a","type":"DataRange1d"},"y_range":{"id":"fe758166-9c33-4115-bec6-df1e0951aaa0","type":"DataRange1d"}},"id":"aa41c407-0e63-4d5d-87d0-e6781ec29fb8","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"aa41c407-0e63-4d5d-87d0-e6781ec29fb8","subtype":"Figure","type":"Plot"},"ticker":{"id":"a4bec563-2e22-49bd-bc31-1b69ee319083","type":"BasicTicker"}},"id":"63fd0555-f5c8-4b81-97c3-a1eb4bd77be5","type":"Grid"},{"attributes":{"plot":null,"text":" Order Book for Bitstamp at 2017-10-02 16:29:21.338665","text_font":"times","text_font_size":{"value":"14pt"}},"id":"33435578-dc76-4558-b317-4297dbd955cf","type":"Title"},{"attributes":{"callback":null},"id":"3f05698f-6721-4260-9dc5-308802ddf95a","type":"DataRange1d"},{"attributes":{},"id":"e209bf0e-2a7b-41b1-81e3-dd1194610461","type":"ToolEvents"},{"attributes":{"label":{"field":"label"},"renderers":[{"id":"8e7c3e3b-a708-45fe-a9e8-d8d60c6ed478","type":"GlyphRenderer"}]},"id":"8812fd79-75c1-4c8c-a7ce-9974d398c3df","type":"LegendItem"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c466b617-0854-46ac-9510-3181f4630ff1","type":"PanTool"},{"id":"394d4820-90d4-43fa-9588-5cb2bcecec9b","type":"WheelZoomTool"},{"id":"26b08b20-ffea-46ae-9e1c-ef770dd7ba82","type":"BoxZoomTool"},{"id":"d0a74531-75d1-4e63-a23a-4023dffff44d","type":"SaveTool"},{"id":"c0f34bad-90be-492c-b6ba-1366896a9280","type":"ResetTool"},{"id":"4afc88f5-d12d-42d7-9351-0e055cbe6650","type":"HelpTool"}]},"id":"8ad8ade5-7c75-4e0c-843f-6260b1dedcd3","type":"Toolbar"},{"attributes":{"axis_label":"USD/BTC","axis_label_text_font":"times","axis_label_text_font_size":{"value":"12pt"},"formatter":{"id":"55368723-a263-4586-ba45-7f73b69757d7","type":"NumeralTickFormatter"},"plot":{"id":"aa41c407-0e63-4d5d-87d0-e6781ec29fb8","subtype":"Figure","type":"Plot"},"ticker":{"id":"a4bec563-2e22-49bd-bc31-1b69ee319083","type":"BasicTicker"}},"id":"c602c728-031d-4f68-8397-d24251ef8173","type":"LinearAxis"},{"attributes":{},"id":"82c410d6-f772-4fde-b8a1-c92ed1592d56","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"fe758166-9c33-4115-bec6-df1e0951aaa0","type":"DataRange1d"},{"attributes":{"format":"=$ 0,0[.]00"},"id":"55368723-a263-4586-ba45-7f73b69757d7","type":"NumeralTickFormatter"},{"attributes":{},"id":"a4bec563-2e22-49bd-bc31-1b69ee319083","type":"BasicTicker"},{"attributes":{},"id":"ac6ad58b-55fc-4ab9-8aa4-7719bbfa747a","type":"BasicTicker"},{"attributes":{"items":[{"id":"8812fd79-75c1-4c8c-a7ce-9974d398c3df","type":"LegendItem"}],"p ...

# %%
plot_order_book(kraken_orderbook, order_count, 'Kraken', sample_time, chart_styling)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f9710a3c-cb02-4f9b-94be-f5057867f570"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f9710a3c-cb02-4f9b-94be-f5057867f570");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f9710a3c-cb02-4f9b-94be-f5057867f570");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f9710a3c-cb02-4f9b-94be-f5057867f570' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3557f6a7-61e9-42f9-b667-9e466f5cb7e7":{"roots":{"references":[{"attributes":{"plot":null,"text":" Order Book for Kraken at 2017-10-02 16:29:21.338665","text_font":"times","text_font_size":{"value":"14pt"}},"id":"a125039e-ced8-420e-b9d0-379f88afcd7c","type":"Title"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"6af077e8-4d70-4342-89d5-87f30b7e1de0","type":"BoxAnnotation"},{"attributes":{"items":[{"id":"e40d3a01-40ae-419b-8ba6-d39363459696","type":"LegendItem"}],"plot":{"id":"d3ab1d56-609a-4d62-9c6b-8ec373cdbad4","subtype":"Figure","type":"Plot"}},"id":"36335021-067c-4cd2-952a-4662c9e44208","type":"Legend"},{"attributes":{"format":"=$ 0,0[.]00"},"id":"e71caa78-1be8-4c9f-a2cb-653c371bd7e5","type":"NumeralTickFormatter"},{"attributes":{"overlay":{"id":"6af077e8-4d70-4342-89d5-87f30b7e1de0","type":"BoxAnnotation"},"plot":{"id":"d3ab1d56-609a-4d62-9c6b-8ec373cdbad4","subtype":"Figure","type":"Plot"}},"id":"51de1c8c-c1ca-4227-b771-2f29d4d7c454","type":"BoxZoomTool"},{"attributes":{},"id":"2b2d29a4-27c8-4340-89e0-d0314e90b2e2","type":"BasicTicker"},{"attributes":{"plot":{"id":"d3ab1d56-609a-4d62-9c6b-8ec373cdbad4","subtype":"Figure","type":"Plot"}},"id":"5eb5944b-5b5f-41e1-8e88-613d360231b0","type":"PanTool"},{"attributes":{"data_source":{"id":"e22dbe04-019c-4ff1-a77f-30a9f78f80cd","type":"ColumnDataSource"},"glyph":{"id":"fb81452a-9265-4829-b258-fd67ad641b31","type":"Patches"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"84c328fc-2e04-493b-a5e9-f63a9b4ec7da","type":"Patches"},"selection_glyph":null},"id":"f6286008-8548-418a-81d2-4343897e5fe8","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"d3ab1d56-609a-4d62-9c6b-8ec373cdbad4","subtype":"Figure","type":"Plot"}},"id":"5e2fc13f-2f40-4bd7-b329-44ffe6686bad","type":"ResetTool"},{"attributes":{"callback":null},"id":"8f5495bd-afb4-45e0-a60b-aac7651da8f7","type":"DataRange1d"},{"attributes":{"plot":{"id":"d3ab1d56-609a-4d62-9c6b-8ec373cdbad4","subtype":"Figure","type":"Plot"}},"id":"18ccedd0-f6e5-47a8-b13b-3abe707b00d4","type":"SaveTool"},{"attributes":{"label":{"field":"label"},"renderers":[{"id":"f6286008-8548-418a-81d2-4343897e5fe8","type":"GlyphRenderer"}]},"id":"e40d3a01-40ae-419b-8ba6-d39363459696","type":"LegendItem"},{"attributes":{"axis_label":"USD/BTC","axis_label_text_font":"times","axis_label_text_font_size":{"value":"12pt"},"formatter":{"id":"e71caa78-1be8-4c9f-a2cb-653c371bd7e5","type":"NumeralTickFormatter"},"plot":{"id":"d3ab1d56-609a-4d62-9c6b-8ec373cdbad4","subtype":"Figure","type":"Plot"},"ticker":{"id":"e24f185d-9381-4131-84fa-b8295946e087","type":"BasicTicker"}},"id":"c48cab47-1821-4a3f-9ddc-f9b011f8a150","type":"LinearAxis"},{"attributes":{"plot":{"id":"d3ab1d56-609a-4d62-9c6b-8ec373cdbad4","subtype":"Figure","type":"Plot"}},"id":"2331eddc-c3e3-4541-8f52-23d630ee4f38","type":"HelpTool"},{"attributes":{"callback":null},"id":"2dcb4823-70f3-455f-a3f7-e7438990c15b","type":"DataRange1d"},{"attributes":{"plot":{"id":"d3ab1d56-609a-4d62-9c6b-8ec373cdbad4","subtype":"Figure","type":"Plot"},"ticker":{"id":"e24f185d-9381-4131-84fa-b8295946e087","type":"BasicTicker"}},"id":"b169317b-9572-4508-a39a-33e102ad63f8","type":"Grid"},{"attributes":{"axis_label":"Liquidity (BTC's)","axis_label_text_font":"times","axis_label_text_font_size":{"value":"12pt"},"formatter":{"id":"640bde63-4092-421e-907d-14eed4f9718b","type":"BasicTickFormatter"},"plot":{"id":"d3ab1d56-609a-4d62-9c6b-8ec373cdbad4","subtype":"Figure","type":"Plot"},"ticker":{"id":"2b2d29a4-27c8-4340-89e0-d0314e90b2e2","type":"BasicTicker"}},"id":"7cea6436-8183-4363-b519-375ffdb6b239","type":"LinearAxis"},{"attributes":{},"id":"640bde63-4092-421e-907d-14eed4f9718b","type":"BasicTickFormatter"},{"attri ...

# %%
plot_order_book(gdax_orderbook, order_count, 'GDAX', sample_time, chart_styling)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="71215ab3-b900-4583-a129-91c9bd16b3b0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("71215ab3-b900-4583-a129-91c9bd16b3b0");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("71215ab3-b900-4583-a129-91c9bd16b3b0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '71215ab3-b900-4583-a129-91c9bd16b3b0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"64ebfcc0-ee7f-4544-ad93-02b33f4c69e9":{"roots":{"references":[{"attributes":{"plot":{"id":"87a26455-e0fa-419a-a5a7-454ebaebb570","subtype":"Figure","type":"Plot"}},"id":"06602c49-ff99-4262-a27f-db69cee8fcca","type":"SaveTool"},{"attributes":{},"id":"298707bb-296e-4138-801e-9e1fee8a9dc8","type":"ToolEvents"},{"attributes":{"plot":null,"text":" Order Book for GDAX at 2017-10-02 16:29:21.338665","text_font":"times","text_font_size":{"value":"14pt"}},"id":"afb9a01b-481e-445b-97cb-49929feb0fce","type":"Title"},{"attributes":{"plot":{"id":"87a26455-e0fa-419a-a5a7-454ebaebb570","subtype":"Figure","type":"Plot"}},"id":"0641dfa9-9b9a-4393-aeae-fcab9f205669","type":"ResetTool"},{"attributes":{"data_source":{"id":"f3d2c2b3-6ca3-4401-a249-4b1909806dcf","type":"ColumnDataSource"},"glyph":{"id":"92817b47-dacb-4d9f-8f0e-beececb872cb","type":"Patches"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e5e9f66c-6dcb-4901-8d6e-a0d2453389ba","type":"Patches"},"selection_glyph":null},"id":"f5da9ca8-4a17-4f43-9719-09b593b9ff7a","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"87a26455-e0fa-419a-a5a7-454ebaebb570","subtype":"Figure","type":"Plot"},"ticker":{"id":"edfa9064-215a-4547-b9f7-c1193ed4706a","type":"BasicTicker"}},"id":"90813ecc-c36f-4e1a-a25f-8f42ef3dd1fe","type":"Grid"},{"attributes":{"axis_label":"Liquidity (BTC's)","axis_label_text_font":"times","axis_label_text_font_size":{"value":"12pt"},"formatter":{"id":"0d96b32f-035e-49bb-8f77-8b17161a8827","type":"BasicTickFormatter"},"plot":{"id":"87a26455-e0fa-419a-a5a7-454ebaebb570","subtype":"Figure","type":"Plot"},"ticker":{"id":"edfa9064-215a-4547-b9f7-c1193ed4706a","type":"BasicTicker"}},"id":"0174733c-ae6c-45aa-8b7c-57eb4ade64c9","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"12cd5997-c102-49f6-a079-f8165c2fa983","type":"PanTool"},{"id":"babf8e10-dae9-4a18-9fb7-ab9375c37e8a","type":"WheelZoomTool"},{"id":"97d98193-b5ac-4d33-a929-521cb5b6d748","type":"BoxZoomTool"},{"id":"06602c49-ff99-4262-a27f-db69cee8fcca","type":"SaveTool"},{"id":"0641dfa9-9b9a-4393-aeae-fcab9f205669","type":"ResetTool"},{"id":"09f9f3e5-439c-43eb-9aed-7a4b4ba8aa4b","type":"HelpTool"}]},"id":"6db818ae-8790-4fc2-bde5-6be06f968743","type":"Toolbar"},{"attributes":{"callback":null},"id":"508b9db8-265f-462c-b997-bcd172fbb261","type":"DataRange1d"},{"attributes":{"label":{"field":"label"},"renderers":[{"id":"f5da9ca8-4a17-4f43-9719-09b593b9ff7a","type":"GlyphRenderer"}]},"id":"eca0f0b0-8423-4e6b-b65f-7f895863bc0a","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"color"},"line_alpha":{"value":0.5},"line_color":{"field":"color"},"line_width":{"value":2},"xs":{"field":"x_axis"},"ys":{"field":"y_axis"}},"id":"92817b47-dacb-4d9f-8f0e-beececb872cb","type":"Patches"},{"attributes":{"items":[{"id":"eca0f0b0-8423-4e6b-b65f-7f895863bc0a","type":"LegendItem"}],"plot":{"id":"87a26455-e0fa-419a-a5a7-454ebaebb570","subtype":"Figure","type":"Plot"}},"id":"3ea7b518-cb21-499d-8b8b-f05271c97e8b","type":"Legend"},{"attributes":{},"id":"a27712e3-75b0-4b80-bf06-b55ff20b3e8a","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"xs":{"field":"x_axis"},"ys":{"field":"y_axis"}},"id":"e5e9f66c-6dcb-4901-8d6e-a0d2453389ba","type":"Patches"},{"attributes":{},"id":"0d96b32f-035e-49bb-8f77-8b17161a8827","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"87a26455-e0fa-419a-a5a7-454ebaebb570","subtype":"Figure","type":"Plot"},"ticker":{"id":"a27712e3-75b0-4b80-bf06-b55ff20b3e8a","type":"BasicTicker"}},"id":"adfc4bb3-4cdb-4319-9c43-09a3df494703","type":"Grid"},{"attributes":{"plot":{"id":"87a26455-e0fa-419a-a5a7-454ebaebb570","subtype":"Figure","type":"Plot"}},"id":"babf8e10-dae9-4a18-9fb7-ab9375c37e8a","type":"WheelZoomTool"},{"attributes":{"callback":nul ...

# %% [markdown]
# Each order book seems to have unique characteristics. It is interesting that Bitstamp had a noticeable spread compared to the other exchanges. GDAX looks like it has the most balanced order book at this particular moment, while both Kraken and Bitstamp clearly have greater buy interest. Also, it is important to note that each visualization is defined by the parameter <i>order_count</i> listed above. The parameter is set for the top 99 orders from each exchange (max capacity from [Crypto Watch](https://cryptowat.ch/)). Unfortunately, it is hard to compare different exchanges like this, with the axes unaligned. The next section will combine different order books on the same visualization so comparison can be done easier.
#
#
# ## 6. Visualizing the Arbitrage
#
# The next function, <i>plot_dual_order_books()</i> will be used to show two order books simultaneously. It was designed with a large number of parameters to provide flexibility when creating the visualization.

# %%
def plot_dual_order_books(ob1, ob2, order_count, e1, e2, ob_time, x_scale, y_scale, styling, align_flag):
    """
    Creates a visualization of two order books on the same graph
    :param ob1: Dataframe - Order book from first exchange
    :param ob2: Dataframe - Order book from first exchange
    :param order_count: Int - number of orders to show in order book (max=99)
    :param e1: String - Name of exchange for ob1_coords 
    :param e2: String - Name of exchange for ob2_coords
    :param ob_time: String - Timestamp
    :param x_scale: List of ints - parameter to define how the graph displays price
    :param y_scale: List of ints - parameter to define how the graph displays liquidity
    :param styling: Dict - Styling parameters
    :param align_flag: Bool - Determines whether vertical lines should be added or not
    """
    
    # Get x/y coordinates for both order books, including bids and asks up to {order_count} 
    ob1_coords  = generate_plot_coordinates(ob1, order_count)   
    ob2_coords  = generate_plot_coordinates(ob2, order_count)    
    
    plot_title = ' Order Book for ' + str(e1) + ' and ' + str(e2) + ' at ' + ob_time
          
    # Create a new plot with a title and two axes
    p = figure(title=plot_title, 
               x_axis_label='USD/BTC', 
               y_axis_label= str(e1) + ' Liquidity (BTC\'s)',
               plot_width=950, 
               plot_height=500,
               x_range=Range1d(x_scale[0], x_scale[1]),
               y_range=Range1d(y_scale[0], y_scale[1]),
               toolbar_location='above'
              )

    # Create second axis
    p.extra_y_ranges = {'ex2': Range1d(start=y_scale[1], end=y_scale[0])}
    
    # Adding the second axis to the plot.  
    p.add_layout(LinearAxis(y_range_name="ex2", axis_label= str(e2) + ' Liquidity (BTC\'s)'), 'right')    
        
    # Create source for first exchange, including coordinates, colors, and legend
    source1 = ColumnDataSource(dict(
        x_axis = [ob1_coords[0], ob1_coords[1]],
        y_axis = [ob1_coords[2], ob1_coords[3]],
        color = ['lightskyblue', 'mediumpurple'],
        label = [str(e1) + ' Bids', str(e1) + ' Asks']
    ))    
   
    # Create source for second exchange, including coordinates, colors, and legend
    source2 = ColumnDataSource(dict(
        x_axis = [ob2_coords[0], ob2_coords[1]],
        y_axis = [ob2_coords[2], ob2_coords[3]],
        color = ['green', 'red'],
        label = [str(e2) + ' Bids', str(e2) + ' Asks']
    )) 
       
    # Plot the first order book 
    p.patches(xs='x_axis', ys='y_axis', color='color', legend='label', 
              alpha=0.5, line_width=2, source=source1)

    # Plot the second order book
    p.patches(xs='x_axis', ys='y_axis', color='color', legend='label', 
              alpha=0.5, line_width=2, y_range_name="ex2", source=source2)
    
    # Adds vertical lines to align the arbitrage
    if align_flag:
        left_vertical = (ob1_coords[1][0], (y_scale[0], y_scale[1]))
        p.line(left_vertical[0], left_vertical[1])  
        right_vertical = (ob2_coords[0][0], (y_scale[0], y_scale[1]))
        p.line(right_vertical[0], right_vertical[1])        
    
    # Graph Formatting
    p.xaxis.formatter = NumeralTickFormatter(format="=$ 0,0[.]00")
    p.title.text_font_size = styling['title_size']
    p.xaxis.axis_label_text_font_size = styling['axis_size']
    p.yaxis.axis_label_text_font_size = styling['axis_size']   
    p.title.text_font = styling['font']
    p.xaxis.axis_label_text_font = styling['font']
    p.yaxis.axis_label_text_font = styling['font']
    p.legend.label_text_font = styling['font']
    p.legend.location = styling['legend_pos']
    p.legend.label_text_font_size = styling['legend_font']

    show(p)

# %%
# Parameters
order_count = 99
x_scale = [4270, 4510]
y_scale = [0, 500]
chart_styling['legend_pos'] = 'bottom_right'

plot_dual_order_books(gdax_orderbook, kraken_orderbook, order_count, 
                      'GDAX', 'Kraken', sample_time, x_scale, y_scale, chart_styling, False)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b983748c-c0c7-40e9-b313-7feba8b057e7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b983748c-c0c7-40e9-b313-7feba8b057e7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b983748c-c0c7-40e9-b313-7feba8b057e7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b983748c-c0c7-40e9-b313-7feba8b057e7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f66d9d33-3525-4079-8d37-e07a67eb53a2":{"roots":{"references":[{"attributes":{},"id":"e166029d-00b0-4301-8779-4cbd7164c46c","type":"BasicTicker"},{"attributes":{"label":{"field":"label"},"renderers":[{"id":"d4dc6adb-23cc-4b53-99ae-446a48424958","type":"GlyphRenderer"}]},"id":"d12cfd3f-7bac-4993-85fe-6c47b5842af4","type":"LegendItem"},{"attributes":{},"id":"1e805e5a-569f-4730-8663-13f3bec0a434","type":"BasicTickFormatter"},{"attributes":{"items":[{"id":"d12cfd3f-7bac-4993-85fe-6c47b5842af4","type":"LegendItem"},{"id":"7ddd2a65-d74c-42db-a858-c963c9181a16","type":"LegendItem"}],"label_text_font":"times","label_text_font_size":{"value":"8pt"},"location":"bottom_right","plot":{"id":"9fb8937f-eb37-4c50-9c06-00ac5e445294","subtype":"Figure","type":"Plot"}},"id":"5977f3d4-d363-47d0-bf6a-f65b4b700348","type":"Legend"},{"attributes":{"data_source":{"id":"0b722dec-4d42-4f0d-a2bb-9a999696058a","type":"ColumnDataSource"},"glyph":{"id":"ab8304d5-fd89-422a-a1bf-91283fdde0f0","type":"Patches"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1ade60a9-83fc-40a7-a497-ccc1669f4a2d","type":"Patches"},"selection_glyph":null,"y_range_name":"ex2"},"id":"f6210cb7-cf97-442e-b459-0ed1c4047716","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"color"},"line_alpha":{"value":0.5},"line_color":{"field":"color"},"line_width":{"value":2},"xs":{"field":"x_axis"},"ys":{"field":"y_axis"}},"id":"ae4e72d0-6e48-4900-8086-a9435a701d49","type":"Patches"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"xs":{"field":"x_axis"},"ys":{"field":"y_axis"}},"id":"0e751bbf-87fd-4aeb-8f6e-054d29960c96","type":"Patches"},{"attributes":{"format":"=$ 0,0[.]00"},"id":"6f179025-967d-49a7-b8c6-05b1f7ac4a3d","type":"NumeralTickFormatter"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"color"},"line_alpha":{"value":0.5},"line_color":{"field":"color"},"line_width":{"value":2},"xs":{"field":"x_axis"},"ys":{"field":"y_axis"}},"id":"ab8304d5-fd89-422a-a1bf-91283fdde0f0","type":"Patches"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"xs":{"field":"x_axis"},"ys":{"field":"y_axis"}},"id":"1ade60a9-83fc-40a7-a497-ccc1669f4a2d","type":"Patches"},{"attributes":{"label":{"field":"label"},"renderers":[{"id":"f6210cb7-cf97-442e-b459-0ed1c4047716","type":"GlyphRenderer"}]},"id":"7ddd2a65-d74c-42db-a858-c963c9181a16","type":"LegendItem"},{"attributes":{"callback":null,"end":4510,"start":4270},"id":"347421e5-7b71-46dc-ac7d-daa1db1b6b6b","type":"Range1d"},{"attributes":{"plot":{"id":"9fb8937f-eb37-4c50-9c06-00ac5e445294","subtype":"Figure","type":"Plot"}},"id":"d20d0f38-65ec-46f9-91b2-fa8fd5f2a700","type":"ResetTool"},{"attributes":{"axis_label":"Kraken Liquidity (BTC's)","axis_label_text_font":"times","axis_label_text_font_size":{"value":"12pt"},"formatter":{"id":"1e805e5a-569f-4730-8663-13f3bec0a434","type":"BasicTickFormatter"},"plot":{"id":"9fb8937f-eb37-4c50-9c06-00ac5e445294","subtype":"Figure","type":"Plot"},"ticker":{"id":"e166029d-00b0-4301-8779-4cbd7164c46c","type":"BasicTicker"},"y_range_name":"ex2"},"id":"276f6266-aa39-403a-b0f6-06d70b7e6e5a","type":"LinearAxis"},{"attributes":{},"id":"4b3f393e-65ae-4dea-8324-035f1b71d1a8","type":"BasicTicker"},{"attributes":{"plot":{"id":"9fb8937f-eb37-4c50-9c06-00ac5e445294","subtype":"Figure","type":"Plot"}},"id":"b7ab381b-738e-4fa0-b467-d299ded8564b","type":"HelpTool"},{"attributes":{"dimension":1,"plot":{"id":"9fb8937f-eb37-4c50-9c06-00ac5e445294","subtype":"Figure","type":"Plot"},"ticker":{"id":"bdc64c70-be8d-4845-88c2-6d8c8955f0ec","type":"BasicTicker"}},"id":"b0a30eb8-dcdb-4b65-a1f5-ad2b67d79241","type":"Grid"},{"attributes":{"plot":{"id":"9fb8937f-eb37-4c50-9c06-00ac5e445294","subtype":"Figure","type":"Plot"}},"id":"baf2e ...

# %% [markdown]
# The image above takes a look at the top 99 bids and asks for both GDAX and Kraken exchanges. At first glance, it might appear that Kraken is the larger exchange, however the truth is quote the opposite. GDAX has so many more orders, that its first 99 bids/asks are only slightly different in price. Now that the order books are aligned on the same price scale, is becomes easier to see where the prices cross. However, improvements can be made to the scaling to allow for a more readable view of the arbitrage opportunity.
#
# First, by enabling the <i>align_flag</i> to true, two vertical lines form a visual aid.

# %%
plot_dual_order_books(gdax_orderbook, kraken_orderbook, order_count, 
                      'GDAX', 'Kraken', sample_time, x_scale, y_scale, chart_styling, True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="02eebc69-29cc-4f95-8e73-60c1e225dd69"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("02eebc69-29cc-4f95-8e73-60c1e225dd69");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("02eebc69-29cc-4f95-8e73-60c1e225dd69");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '02eebc69-29cc-4f95-8e73-60c1e225dd69' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"48b1abbc-3edf-458f-bfbe-85285ead0cd8":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"color"},"line_alpha":{"value":0.5},"line_color":{"field":"color"},"line_width":{"value":2},"xs":{"field":"x_axis"},"ys":{"field":"y_axis"}},"id":"2f617d40-ee30-49e4-9462-5e36b552bc7d","type":"Patches"},{"attributes":{"data_source":{"id":"978e64c4-17c0-4eb5-8d43-e5596c67731c","type":"ColumnDataSource"},"glyph":{"id":"2f617d40-ee30-49e4-9462-5e36b552bc7d","type":"Patches"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"981e044d-bc13-4279-ad05-7ba5d0e75843","type":"Patches"},"selection_glyph":null},"id":"91cda4ef-ae27-48eb-ae67-b875d16115eb","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"60be4bdd-bb1a-471e-832a-7f91d7c73051","subtype":"Figure","type":"Plot"}},"id":"916abe72-c28f-4d69-848f-5e80d90fb6da","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"xs":{"field":"x_axis"},"ys":{"field":"y_axis"}},"id":"981e044d-bc13-4279-ad05-7ba5d0e75843","type":"Patches"},{"attributes":{"callback":null,"end":4510,"start":4270},"id":"312af573-2738-49d9-8376-2a35ab5904bf","type":"Range1d"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"value":4410.1},"y":{"field":"y"}},"id":"384a6302-7108-4af5-90a2-372e36ff34d7","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"value":4408.44},"y":{"field":"y"}},"id":"3375cb36-6016-42b6-b766-1e297f4b30ce","type":"Line"},{"attributes":{"data_source":{"id":"723230dd-7d5f-4a8d-acce-ab5ecee90c70","type":"ColumnDataSource"},"glyph":{"id":"384a6302-7108-4af5-90a2-372e36ff34d7","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"efa66802-21ce-4b38-a221-f9238cd6d012","type":"Line"},"selection_glyph":null},"id":"6d8d0509-e884-4fbf-81e0-f34d37e759db","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"60be4bdd-bb1a-471e-832a-7f91d7c73051","subtype":"Figure","type":"Plot"}},"id":"11094009-1e5a-4232-af82-2df0780e81e7","type":"SaveTool"},{"attributes":{},"id":"18011e82-4005-4e10-928a-7de7ad52e8c0","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"value":4408.44},"y":{"field":"y"}},"id":"6431c449-48ec-4a78-8401-2f2073e5fd6d","type":"Line"},{"attributes":{"plot":{"id":"60be4bdd-bb1a-471e-832a-7f91d7c73051","subtype":"Figure","type":"Plot"}},"id":"b8e0763c-c3c3-4338-9d07-16fd20cc0f24","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["y"],"data":{"y":[0,500]}},"id":"723230dd-7d5f-4a8d-acce-ab5ecee90c70","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"f447ac4c-00af-476b-8f57-e240a72544d3","type":"BoxAnnotation"},"plot":{"id":"60be4bdd-bb1a-471e-832a-7f91d7c73051","subtype":"Figure","type":"Plot"}},"id":"0ce2cc83-aa79-4f60-8530-afb6e1ce27fe","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"color"},"line_alpha":{"value":0.5},"line_color":{"field":"color"},"line_width":{"value":2},"xs":{"field":"x_axis"},"ys":{"field":"y_axis"}},"id":"329927e9-87fd-420f-a623-364ab1f97cc7","type":"Patches"},{"attributes":{"label":{"field":"label"},"renderers":[{"id":"91cda4ef-ae27-48eb-ae67-b875d16115eb","type":"GlyphRenderer"}]},"id":"e1aade02-407d-447c-a15d-9410689645a8","type":"LegendItem"},{"attributes":{"data_source":{"id":"53ac515b-61b2-4a7c-81f4-23d96f68036d","type":"ColumnDataSource"},"glyph":{"id":"329927e9-87fd-420f-a623-364ab1f97cc7","type":"Patches"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2368ed9f-43a6-4c00-9372-a10b66ef4d95","type":"Patches"},"selection_glyph":null,"y_range_name":"ex2"},"id":"bbdace9c-2d60-4946-9278-569218202dcc","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"3b744dd4-7604-4a72-8c3e-2de2b65e9c10","type":"ColumnDataSource"},"glyph":{"id":"6431c449-48ec-4a78-8401-2f2073e5fd6d","type":"Line"}, ...

# %% [markdown]
# The graph is still somewhat hard to see, so the next step is changing the <i>order_count, x_scale, and y_scale</i> parameters. The next three graphs give a better view of the arbitrage, and show how much liquidity is available.

# %%
order_count = 99
x_scale = [4350, 4460]
y_scale = [0, 300]
chart_styling['legend_pos'] = 'bottom_left'

plot_dual_order_books(gdax_orderbook, kraken_orderbook, order_count, 
                      'GDAX', 'Kraken', sample_time, x_scale, y_scale, chart_styling, True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8c8e8216-9640-437f-856d-5e5787eb7817"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8c8e8216-9640-437f-856d-5e5787eb7817");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8c8e8216-9640-437f-856d-5e5787eb7817");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8c8e8216-9640-437f-856d-5e5787eb7817' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"01aa6c5f-7105-42ad-8453-f074947cd544":{"roots":{"references":[{"attributes":{"format":"=$ 0,0[.]00"},"id":"669bf818-64f2-4fb8-8bc3-5e75a17f6f31","type":"NumeralTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"value":4408.44},"y":{"field":"y"}},"id":"9e7a701f-fb7b-4b05-beab-2e1962a58d5b","type":"Line"},{"attributes":{"data_source":{"id":"9cbfe01c-4576-4513-b169-92f3ec2af78a","type":"ColumnDataSource"},"glyph":{"id":"b2c80bd2-ee52-470b-be88-d2d610eff1c6","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c5df3643-80a0-4184-bcd4-07c8e6ed86ae","type":"Line"},"selection_glyph":null},"id":"f0cd0273-48be-4cc8-b582-4a5f5c283879","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"value":4410.1},"y":{"field":"y"}},"id":"c5df3643-80a0-4184-bcd4-07c8e6ed86ae","type":"Line"},{"attributes":{"callback":null,"end":300},"id":"4b78a4a8-1354-4d88-a12e-4a03eb51b8e1","type":"Range1d"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"xs":{"field":"x_axis"},"ys":{"field":"y_axis"}},"id":"a2e26f18-1346-4700-bf33-655e61e4aa72","type":"Patches"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"value":4410.1},"y":{"field":"y"}},"id":"b2c80bd2-ee52-470b-be88-d2d610eff1c6","type":"Line"},{"attributes":{"data_source":{"id":"8238061a-3b64-48b7-b0e6-544c8a5c9d93","type":"ColumnDataSource"},"glyph":{"id":"3e0fc8b2-7952-4e71-b366-bc88cb434020","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9e7a701f-fb7b-4b05-beab-2e1962a58d5b","type":"Line"},"selection_glyph":null},"id":"88a4536c-c95c-47a6-b10d-8135b775e723","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":4460,"start":4350},"id":"f331b7bb-46ec-4ec5-b256-b9270db27da6","type":"Range1d"},{"attributes":{"below":[{"id":"fae26272-8c39-4779-9561-8b00e2eecebd","type":"LinearAxis"}],"extra_y_ranges":{"ex2":{"id":"9c22ee87-3d3c-4baf-af67-3a15c24aa02f","type":"Range1d"}},"left":[{"id":"fa3a5490-b121-4751-b9ac-58ccc9f4a75c","type":"LinearAxis"}],"plot_height":500,"plot_width":950,"renderers":[{"id":"fae26272-8c39-4779-9561-8b00e2eecebd","type":"LinearAxis"},{"id":"72ba0376-a955-4fdf-8c9f-41c069a76a39","type":"Grid"},{"id":"fa3a5490-b121-4751-b9ac-58ccc9f4a75c","type":"LinearAxis"},{"id":"5c3889db-b19c-45e2-9889-6621da947629","type":"Grid"},{"id":"1eca1573-c41c-4ebd-9053-f85a0b561cc8","type":"BoxAnnotation"},{"id":"c4665603-6d3f-4dc3-94b0-032d847680d2","type":"LinearAxis"},{"id":"a7cc9b42-1f4f-4c42-8ef7-c0aedd591d95","type":"Legend"},{"id":"69ee149d-5cc0-4657-b8fa-9147d81d8761","type":"GlyphRenderer"},{"id":"c7ae2025-392c-445f-b81d-070dd48bf81b","type":"GlyphRenderer"},{"id":"88a4536c-c95c-47a6-b10d-8135b775e723","type":"GlyphRenderer"},{"id":"f0cd0273-48be-4cc8-b582-4a5f5c283879","type":"GlyphRenderer"}],"right":[{"id":"c4665603-6d3f-4dc3-94b0-032d847680d2","type":"LinearAxis"}],"title":{"id":"991aa597-2a02-43de-9073-979036ccacf0","type":"Title"},"tool_events":{"id":"4373b839-ff6b-4a0e-96f4-4b28dac6476e","type":"ToolEvents"},"toolbar":{"id":"a71d66b6-7200-4bf5-bc4a-180f827b5503","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"f331b7bb-46ec-4ec5-b256-b9270db27da6","type":"Range1d"},"y_range":{"id":"4b78a4a8-1354-4d88-a12e-4a03eb51b8e1","type":"Range1d"}},"id":"1d4b9958-99ab-4d82-8683-c8f9745ac03e","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["y"],"data":{"y":[0,300]}},"id":"9cbfe01c-4576-4513-b169-92f3ec2af78a","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"field":"color"},"line_alpha":{"value":0.5},"line_color":{"field":"color"},"line_width":{"value":2},"xs":{"field":"x_axis"},"ys":{"field":"y_axis"}},"id":"0e93166e-ac9b-4ed9-83bc-96ad821a9b0f","type":"Patches"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color": ...

# %%
# Parameters
order_count = 50
x_scale = [4400, 4420]
y_scale = [0, 100]

chart_styling['legend_pos'] = 'bottom_right'

plot_dual_order_books(gdax_orderbook, kraken_orderbook, order_count, 
                      'GDAX', 'Kraken', sample_time, x_scale, y_scale, chart_styling, True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1fb0f492-e1ed-4a6b-9a46-21c82cd743d1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1fb0f492-e1ed-4a6b-9a46-21c82cd743d1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1fb0f492-e1ed-4a6b-9a46-21c82cd743d1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1fb0f492-e1ed-4a6b-9a46-21c82cd743d1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"af0ee4ec-74d3-450f-8582-a63c0e2e4402":{"roots":{"references":[{"attributes":{"data_source":{"id":"8774caa5-65e9-431c-acd9-70f054975806","type":"ColumnDataSource"},"glyph":{"id":"0578ba6e-f20a-49b3-81a7-60f69ae94c35","type":"Patches"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ee79c638-a961-4e97-865b-ee943aa41538","type":"Patches"},"selection_glyph":null,"y_range_name":"ex2"},"id":"8215fdbc-0561-4dd6-8815-cf063a7b33cf","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y"],"data":{"y":[0,100]}},"id":"0d6d9492-8320-4565-9dfe-75c6bad23d21","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"26b0ff72-4350-48b1-81ac-e21f632ae05e","type":"ColumnDataSource"},"glyph":{"id":"6bb83542-65d3-426e-802d-567583330af6","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3907c66e-dd7b-4c06-bdb9-51add73d6a99","type":"Line"},"selection_glyph":null},"id":"436d1c12-254d-4776-8dd7-54d3816c65f5","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"value":4410.1},"y":{"field":"y"}},"id":"6bb83542-65d3-426e-802d-567583330af6","type":"Line"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"xs":{"field":"x_axis"},"ys":{"field":"y_axis"}},"id":"ee79c638-a961-4e97-865b-ee943aa41538","type":"Patches"},{"attributes":{"format":"=$ 0,0[.]00"},"id":"70040219-d504-412b-9ec9-09cb0e8cfa04","type":"NumeralTickFormatter"},{"attributes":{"callback":null,"end":4420,"start":4400},"id":"b6403344-6563-4c21-8075-6b9b7be9b80a","type":"Range1d"},{"attributes":{"below":[{"id":"5b94b55b-80a7-43dd-b9f6-3717609e042c","type":"LinearAxis"}],"extra_y_ranges":{"ex2":{"id":"1a3328ca-dce2-455f-ac84-b49ab8c04aa9","type":"Range1d"}},"left":[{"id":"14668604-3591-469e-8a15-8cbeb12795a3","type":"LinearAxis"}],"plot_height":500,"plot_width":950,"renderers":[{"id":"5b94b55b-80a7-43dd-b9f6-3717609e042c","type":"LinearAxis"},{"id":"7c8927d6-74e1-4f98-9dda-a1b0591148c2","type":"Grid"},{"id":"14668604-3591-469e-8a15-8cbeb12795a3","type":"LinearAxis"},{"id":"9e6c7581-2867-4706-aee7-d635f400e516","type":"Grid"},{"id":"c73be3ea-e303-402f-ba5a-77b486ee603a","type":"BoxAnnotation"},{"id":"6eb9dc06-aa2b-44e4-b7be-21a62feac30e","type":"LinearAxis"},{"id":"7cf8dbcb-a901-443b-86f3-607c96e15a36","type":"Legend"},{"id":"7cc8400d-f3d4-46e9-ba45-96f7c7bd3a16","type":"GlyphRenderer"},{"id":"8215fdbc-0561-4dd6-8815-cf063a7b33cf","type":"GlyphRenderer"},{"id":"90f08175-716b-49c3-8ad7-5cb07b2f505f","type":"GlyphRenderer"},{"id":"436d1c12-254d-4776-8dd7-54d3816c65f5","type":"GlyphRenderer"}],"right":[{"id":"6eb9dc06-aa2b-44e4-b7be-21a62feac30e","type":"LinearAxis"}],"title":{"id":"b8606583-f707-4be3-92cb-45bafe94d885","type":"Title"},"tool_events":{"id":"2a260082-08fe-4f96-945a-7f2607755374","type":"ToolEvents"},"toolbar":{"id":"2791e431-c775-41c7-90c7-8589cedb2eed","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"b6403344-6563-4c21-8075-6b9b7be9b80a","type":"Range1d"},"y_range":{"id":"6b8c92a6-b7e7-4065-91e7-0ee58f06b76f","type":"Range1d"}},"id":"055c7c81-7481-4fac-8299-bf649f3a2bff","subtype":"Figure","type":"Plot"},{"attributes":{"axis_label":"Kraken Liquidity (BTC's)","axis_label_text_font":"times","axis_label_text_font_size":{"value":"12pt"},"formatter":{"id":"3d0d07db-6ada-4c7b-80f7-ac4efb1939d4","type":"BasicTickFormatter"},"plot":{"id":"055c7c81-7481-4fac-8299-bf649f3a2bff","subtype":"Figure","type":"Plot"},"ticker":{"id":"f3fd17b3-4b69-4f78-8de8-f6b5225f1da4","type":"BasicTicker"},"y_range_name":"ex2"},"id":"6eb9dc06-aa2b-44e4-b7be-21a62feac30e","type":"LinearAxis"},{"attributes":{"axis_label":"GDAX Liquidity (BTC's)","axis_label_text_font":"times","axis_label_text_font_size":{"value":"12pt"},"formatter":{"id":"960bb53f-d094-43fb-be61-19086d581444","type":"BasicTickFormatter"},"plot":{"id":"055c7c81-7481-4fac-8299-bf649f3a2bff","subtype":"Figu ...

# %%
# Parameters
order_count = 25
x_scale = [4405, 4415]
y_scale = [0, 30]
chart_styling['legend_pos'] = 'bottom_right'

plot_dual_order_books(gdax_orderbook, kraken_orderbook, order_count, 
                      'GDAX', 'Kraken', sample_time, x_scale, y_scale, chart_styling, True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fa2a43fd-540f-4517-8e2c-d23abbd24f4e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("fa2a43fd-540f-4517-8e2c-d23abbd24f4e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fa2a43fd-540f-4517-8e2c-d23abbd24f4e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fa2a43fd-540f-4517-8e2c-d23abbd24f4e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6fc76593-02e5-4d06-aec7-8c1abce51108":{"roots":{"references":[{"attributes":{"plot":{"id":"06521643-86be-48a4-a336-ffa67eb0b092","subtype":"Figure","type":"Plot"}},"id":"23566def-e805-413a-ae93-afb58e58786d","type":"PanTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"69e4e464-7683-4811-af01-00df37b3efac","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["y"],"data":{"y":[0,30]}},"id":"52653cfc-b1de-49e0-9ba4-1693ddd1515d","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"06521643-86be-48a4-a336-ffa67eb0b092","subtype":"Figure","type":"Plot"}},"id":"56795427-6dbd-4aff-bf38-22c4b115058e","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"69e4e464-7683-4811-af01-00df37b3efac","type":"BoxAnnotation"},"plot":{"id":"06521643-86be-48a4-a336-ffa67eb0b092","subtype":"Figure","type":"Plot"}},"id":"918c6ae9-acd6-403f-90c1-35811655312f","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"06521643-86be-48a4-a336-ffa67eb0b092","subtype":"Figure","type":"Plot"}},"id":"14aa0edf-f4a2-4638-8809-68d14c07117c","type":"SaveTool"},{"attributes":{},"id":"de5bcb4f-af2c-4ac7-a55c-071c45ac52a0","type":"BasicTicker"},{"attributes":{"items":[{"id":"568dc33c-0825-438b-9b51-129398b28565","type":"LegendItem"},{"id":"f1ee783c-544b-41f1-bbc7-ca7b0f6c711c","type":"LegendItem"}],"label_text_font":"times","label_text_font_size":{"value":"8pt"},"location":"bottom_right","plot":{"id":"06521643-86be-48a4-a336-ffa67eb0b092","subtype":"Figure","type":"Plot"}},"id":"2805787d-6500-45f4-983e-acd0b13c9b2d","type":"Legend"},{"attributes":{"dimension":1,"plot":{"id":"06521643-86be-48a4-a336-ffa67eb0b092","subtype":"Figure","type":"Plot"},"ticker":{"id":"e05ba241-fda1-4583-bff3-3652dd0361a4","type":"BasicTicker"}},"id":"16039cad-a0b7-4537-af11-8cbd86d92861","type":"Grid"},{"attributes":{"plot":{"id":"06521643-86be-48a4-a336-ffa67eb0b092","subtype":"Figure","type":"Plot"}},"id":"c86b9658-56a7-4cbc-954d-9cb242ee5afb","type":"ResetTool"},{"attributes":{"axis_label":"Kraken Liquidity (BTC's)","axis_label_text_font":"times","axis_label_text_font_size":{"value":"12pt"},"formatter":{"id":"e7c46145-f65f-4a8e-b1ac-0eab59983a19","type":"BasicTickFormatter"},"plot":{"id":"06521643-86be-48a4-a336-ffa67eb0b092","subtype":"Figure","type":"Plot"},"ticker":{"id":"25a21f9d-7e1a-4647-a7bb-e5b1bdb85076","type":"BasicTicker"},"y_range_name":"ex2"},"id":"254da6ae-4bc4-434a-972e-eb38fcf5c53b","type":"LinearAxis"},{"attributes":{"plot":{"id":"06521643-86be-48a4-a336-ffa67eb0b092","subtype":"Figure","type":"Plot"}},"id":"0b6d7e08-aad4-4e06-a8b7-efbcff3ac977","type":"HelpTool"},{"attributes":{"data_source":{"id":"52653cfc-b1de-49e0-9ba4-1693ddd1515d","type":"ColumnDataSource"},"glyph":{"id":"bfe29b42-82fa-4d1e-826e-bfa47205328e","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3c2ba974-a997-48e5-b4fb-bba4e6f673bb","type":"Line"},"selection_glyph":null},"id":"6ccd7628-b5c6-48e8-a802-c2e977420e3a","type":"GlyphRenderer"},{"attributes":{},"id":"25a21f9d-7e1a-4647-a7bb-e5b1bdb85076","type":"BasicTicker"},{"attributes":{"data_source":{"id":"5ad95b0d-d295-4e34-9784-4c61b0713028","type":"ColumnDataSource"},"glyph":{"id":"c4051aac-5c0d-4ad7-bec4-72eda13ad063","type":"Patches"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"189259a6-f283-488a-82a1-ca250626f990","type":"Patches"},"selection_glyph":null},"id":"fd02f5a3-e9b6-47fd-9132-a8ccf3c0d106","type":"GlyphRenderer"},{"attributes":{"label":{"field":"label"},"renderers":[{"id":"fd02f5a3-e9b6-47fd-9132-a8ccf3c0d106","type":"GlyphRenderer"}]},"id":"568dc33c-0825-438b-9b51-129398b28565","type":"LegendItem"},{"attributes":{"callback":null,"end":0,"start":30},"id":"12a562fb ...

# %% [markdown]
# The final graph shows the top 25 orders, but is scaled on the x-axis ($/BTC) to zoom in on the arbitrage, with the y-axis (volume) scaled down to 30 BTC's. To get an intuition about how much Bitcoin could actually be purchased, its whichever shape (liquidity) is smaller between the two horizontal lines. In this case, its GDAX Asks which has the smaller shaper compared to Kraken Bids. So the arbitrage would include buying GDAX and selling Kraken. It can also be roughly estimated that about 5 Bitcoins can be traded.
#
# ## 7. Calculating Arbitrage Profit
#
# This section will be dedicated to calculating the actual profit that could be achieved by this arbitrage. The logic presented below is based on the assumption that purchase of Bitcoin from GDAX and selling of Bitcoin from Kraken occur simultaneously. Of course this is not realistic, but the process acts as a prerequisite for calculating profits in an actual trading model. First, a review of the order books from both GDAX and Kraken.

# %%
gdax_orderbook.head(10)
# Out:
#    bid_liquidity  bid_volume  bid_price  ask_price  ask_volume  ask_liquidity
# 0        6.11000     6.11000    4408.43    4408.44    1.330000       1.330000
# 1        8.11000     2.00000    4408.42    4408.45    0.010000       1.340000
# 2        8.36650     0.25650    4408.35    4408.46    0.010000       1.350000
# 3        8.61650     0.25000    4408.20    4408.50    0.098697       1.448697
# 4        8.63850     0.02200    4408.05    4409.08    3.670000       5.118697
# 5       13.18239     4.54389    4408.01    4409.20    0.010000       5.128697
# 6       14.22039     1.03800    4408.00    4409.44    0.022700       5.151397
# 7       14.24339     0.02300    4407.00    4410.03    0.010000       5.161397
# 8       14.29339     0.05000    4406.91    4410.44    0.879000       6.040397
# 9       16.79339     2.50000    4405.60    4410.63    0.161014       6.201411

# %%
kraken_orderbook.head(10)
# Out:
#    bid_liquidity  bid_volume  bid_price  ask_price  ask_volume  ask_liquidity
# 0          3.399       3.399     4410.1     4410.5       0.014          0.014
# 1         10.198       6.799     4410.0     4410.6       0.224          0.238
# 2         10.282       0.084     4407.2     4412.3       0.151          0.389
# 3         10.302       0.020     4405.8     4414.7       1.500          1.889
# 4         10.314       0.012     4405.1     4416.1       0.428          2.317
# 5         11.271       0.957     4405.0     4418.8       0.005          2.322
# 6         12.271       1.000     4403.7     4421.3       1.372          3.694
# 7         13.771       1.500     4402.9     4421.4       0.290          3.984
# 8         13.781       0.010     4402.3     4422.5       0.180          4.164
# 9         14.357       0.576     4401.6     4422.6       2.938          7.102

# %% [markdown]
# The following method <i>determine_arbitrage_orders()</i> will determine the maximum liquidity that can be used for the trade (the smaller of the two shapes) and calculates which orders to be bought and then sold.

# %%
def determine_arbitrage_orders(ob1, ob2):
    """
    Filters the orders that can be bough and sold for an arbitrage
    :param ob1: Dataframe - The first order book 
    :param ob2: Dataframe - The second order book
    :return: Tuple of DataFrames - filtered by orders that con be arbitraged
    """
    
    # Determine which exchange is cheaper to buy
    low_exchange = pd.DataFrame()
    high_exchange = pd.DataFrame()
    
    if ob1['ask_price'][0] > ob2['ask_price'][0]:
        low_exchange = ob2[['ask_price', 'ask_volume', 'ask_liquidity']].copy()
        high_exchange = ob1[['bid_price', 'bid_volume', 'bid_liquidity']].copy()
    else:
        low_exchange = ob1[['ask_price', 'ask_volume', 'ask_liquidity']].copy()
        high_exchange = ob2[['bid_price', 'bid_volume', 'bid_liquidity']].copy()
      
    
    # Determine lowest ask from cheaper exchange
    lowest_ask = low_exchange['ask_price'][0]
    
    # Determine highest bid from other exchange
    highest_bid = high_exchange['bid_price'][0]
    
    
    # Get orders that can be arbitraged
    buy_orders = low_exchange[low_exchange['ask_price'] < highest_bid]   
    sell_orders = high_exchange[high_exchange['bid_price'] > lowest_ask]
    
    return buy_orders, sell_orders
    
       
buy_orders, sell_orders = determine_arbitrage_orders(gdax_orderbook, kraken_orderbook)

# %% [markdown]
# The following dataframes show that eight orders can be purchased from GDAX totaling 5.161397 BTC, while the next step would be to sell 5.161397 orders on Kraken, taking the first order, and a portion of the second order.

# %%
buy_orders
# Out:
#    ask_price  ask_volume  ask_liquidity
# 0    4408.44    1.330000       1.330000
# 1    4408.45    0.010000       1.340000
# 2    4408.46    0.010000       1.350000
# 3    4408.50    0.098697       1.448697
# 4    4409.08    3.670000       5.118697
# 5    4409.20    0.010000       5.128697
# 6    4409.44    0.022700       5.151397
# 7    4410.03    0.010000       5.161397

# %%
sell_orders
# Out:
#    bid_price  bid_volume  bid_liquidity
# 0     4410.1       3.399          3.399
# 1     4410.0       6.799         10.198

# %% [markdown]
# Finally, the method <i>calculate_profit()</i> will take the weighted sum of both orders to determine exactly how much profit would be made by this hypothetical arbitrage.

# %%
def calculate_profit(buy_orders, sell_orders):
    """
    Calculates and prints the total profit made from the arbitrage 
    :param buy_orders: DataFrame - orders to buy
    :param sell_orders: DataFrame - orders to sell
    """
    
    # Determine weighted price of buy orders
    buy_orders['total_price'] = (buy_orders['ask_price'] * buy_orders['ask_volume']).cumsum()

    # Get last sell order since it will most likely be a partial
    last_sell_order = sell_orders.iloc[-1]
    sell_orders = sell_orders[:-1]

    # Calculate the liquidity to be used for the final order
    remaining_liquidity = buy_orders.iloc[-1]['ask_liquidity']
    for index, order in sell_orders.iterrows():
        remaining_liquidity -= order['bid_liquidity']

    sell_orders['total_price'] = (sell_orders['bid_price'] * sell_orders['bid_volume']).cumsum()

    # Determine weighted price of the final partial trade
    last_partial_order_price = last_sell_order['bid_price'] * remaining_liquidity

    # Total selling orders with the partial
    total_sell_price = sell_orders.iloc[-1]['total_price'] + last_partial_order_price
    total_buy_price = buy_orders.iloc[-1]['total_price']
   
    print('Total price paid for buying: ' + locale.currency(total_buy_price, grouping=True))
    print('Total price received for selling: ' + locale.currency(total_sell_price, grouping=True))
    
    arbitrage_profit = total_sell_price - total_buy_price
    print('Arbitrage profit: ' + locale.currency(arbitrage_profit, grouping=True))
    
calculate_profit(buy_orders, sell_orders)
# Out:
# Total price paid for buying: $22,756.11
# Total price received for selling: $22,762.10
# Arbitrage profit: $5.99

# %% [markdown]
# ## 8. Conclusion
# The visualizations used in this lab has given some insight of the market microstructure of Bitcoin markets. The amount of liquidity could be gauged at by the order book, and the ability to determine just how balanced the book was could be estimated. In section 6, the comparison of two order books in the same visualization gave an idea of just how much liquidity is available during an arbitrage opportunity.
#
# Keep in mind this was a very granulated analysis, focusing on just one microsecond of the order book. Future work will be done to look at the trends of the order book and how liquidity changes over time. Once the liquidity can be properly modeled, a more accurate understanding of how much profit can be made from an arbitrage trading strategy.

# %% [markdown]
# References: <br>
#     (1) http://rickyhan.com/jekyll/update/2017/09/24/visualizing-order-book.html
